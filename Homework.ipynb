# %% [markdown]
# <a href="https://colab.research.google.com/github/EstuardoA5/BTE320/blob/main/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework

# %% [markdown]
# ## Assignment 1: Quality Control
#
# A quality control manager would like to find the average weight of a list of weights. Prior experience indicates that the first two measures are atypical, and the practice is to exclude these from the average calculation.
#
# Write a program that calculates the average of a list of numbers that given as inputs from the user, excluding the first two values.
#
# For your program, you must define and use the following functions:
# - `getValues(n)`: Prompt the user for `n` values, returns the list
# - `calcAverage(alist)`: Calculates the average from the list

# %%
def getValues(n):
    values = []
    for i in range(n):
        values.append(float(input(f"Enter value {i + 1}: ")))
    return values

def calcAverage(alist):
    if len(alist) < 3:
        return 0.0
    return sum(alist[2:]) / len(alist[2:])

if __name__ == '__main__':
    num_values = int(input("How many values do you want to enter? "))
    user_values = getValues(num_values)
    average_result = calcAverage(user_values)
    print(f"The average of the values (excluding the first two) is: {average_result:.2f}")
# Out:
# How many values do you want to enter? 5
# Enter value 1: 3
# Enter value 2: 3
# Enter value 3: 5
# Enter value 4: 10
# Enter value 5: 5
# The average of the values (excluding the first two) is: 6.67

# %% [markdown]
# ## Assignment 2: Parking Garage
#
# Write a program to compute the fee for parking in a garage for a number of hours.
#
# The program should:
# - Prompt the user for how many hours parked
# - Calculate the fee based on the following rules:
#   - $2.50/hour
#
#   - minimum fee is $6.00
#
#   - maximum fee is $20.00
# - Print the result
#
# For your program, define and use the following two functions:
# ```python
# # use input() to prompt for the # of hours parked, return this value
# def getParkingHours()
#
# # takes as input hours (a number), returns the parking fee
# def calcParkingFee()
# ```

# %%
def getParkingHours():
    hours_parked = float(input("Enter how many hours parked: "))
    return hours_parked

def calcParkingFee(hours):
    base_fee = hours * 2.50


    if base_fee < 6.00:
        final_fee = 6.00
    else:
        final_fee = base_fee


    if final_fee > 20.00:
        final_fee = 20.00

    return final_fee


if __name__ == '__main__':
    hours = getParkingHours()
    fee = calcParkingFee(hours)
    print(f"The parking fee is: ${fee:.2f}")
# Out:
# Enter how many hours parked: 5
# The parking fee is: $12.50

# %% [markdown]
# ## Assignment 3: Tuition
#
# A college charges tuition according to the following:
# - 12 or more credits: $20,000/semester
#
# - 1-11 credits: $1,200 + $1,700 per credit
#
# Write a program that prompts the user for a number of credits and determines and displays the tuition for the semester. As part of your program, define and use the following function:
# ```python
# def calcTuition(credits)
# ```
# The function returns the tuition for a given number of credits

# %%
def calcTuition(credits):
    if credits >= 12:
        return 20000.00
    elif credits >= 1 and credits <= 11:
        return 1200 + (1700 * credits)
    else:
        return 0.00 # Assuming 0 credits means 0 tuition

if __name__ == '__main__':
    num_credits = int(input("Enter the number of credits: "))
    tuition_fee = calcTuition(num_credits)
    print(f"The tuition for {num_credits} credits is: ${tuition_fee:.2f}")
